# %%
import pandas
pandas.set_option('display.max_columns', None)

df=pandas.read_json('1x1_matches_dataset_corrected.json')
tech_tree = pandas.read_json('../Projeto 1/Scraper/Civilization_Dataset.json')

def get_team1_specs():
    tech_tree_t1['militiaLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'militiaLine'])
    #tech_tree_t1['militiaLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'militiaLine'])
    #tech_tree_t1['militiaLine1']/=2

    tech_tree_t1['spearmanLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'spearmanLine'])
    #tech_tree_t1['spearmanLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'spearmanLine'])
    #tech_tree_t1['spearmanLine1']/=2

    tech_tree_t1['EaglescoutLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'EaglescoutLine'])
    #tech_tree_t1['EaglescoutLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'EaglescoutLine'])
    #tech_tree_t1['EaglescoutLine1']/=2

    tech_tree_t1['has_supplies1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_supplies'])
    #tech_tree_t1['has_supplies1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_supplies'])
    #tech_tree_t1['has_supplies1']/=2

    tech_tree_t1['has_squires1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_squires'])
    #tech_tree_t1['has_squires1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_squires'])
    #tech_tree_t1['has_squires1']/=2

    tech_tree_t1['has_arson1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_arson'])
    #tech_tree_t1['has_arson1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_arson'])
    #tech_tree_t1['has_arson1']/=2

    tech_tree_t1['archerLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'archerLine'])
    #tech_tree_t1['archerLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'archerLine'])
    #tech_tree_t1['archerLine1']/=2

    tech_tree_t1['skirmisherLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'skirmisherLine'])
    #tech_tree_t1['skirmisherLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'skirmisherLine'])
    #tech_tree_t1['skirmisherLine1']/=2

    tech_tree_t1['handcanoneerLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'handcanoneerLine'])
    #tech_tree_t1['handcanoneerLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'handcanoneerLine'])
    #tech_tree_t1['handcanoneerLine1']/=2

    tech_tree_t1['cavalryarcherLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarcherLine'])
    #tech_tree_t1['cavalryarcherLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarcherLine'])
    #tech_tree_t1['cavalryarcherLine1']/=2

    tech_tree_t1['has_thumbring1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_thumbring'])
    #tech_tree_t1['has_thumbring1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_thumbring'])
    #tech_tree_t1['has_thumbring1']/=2

    tech_tree_t1['has_parthiantactics1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_parthiantactics'])
    #tech_tree_t1['has_parthiantactics1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_parthiantactics'])
    #tech_tree_t1['has_parthiantactics1']/=2

    tech_tree_t1['scoutLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'scoutLine'])
    #tech_tree_t1['scoutLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'scoutLine'])
    #tech_tree_t1['scoutLine1']/=2

    tech_tree_t1['knightLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'knightLine'])
    #tech_tree_t1['knightLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'knightLine'])
    #tech_tree_t1['knightLine1']/=2

    tech_tree_t1['camelriderLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'camelriderLine'])
    #tech_tree_t1['camelriderLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'camelriderLine'])
    #tech_tree_t1['camelriderLine1']/=2

    tech_tree_t1['battleelephantLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'battleelephantLine'])
    #tech_tree_t1['battleelephantLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'battleelephantLine'])
    #tech_tree_t1['battleelephantLine1']/=2

    tech_tree_t1['steppelancerLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'steppelancerLine'])
    #tech_tree_t1['steppelancerLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'steppelancerLine'])
    #tech_tree_t1['steppelancerLine1']/=2

    tech_tree_t1['has_bloodlines1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_bloodlines'])
    #tech_tree_t1['has_bloodlines1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_bloodlines'])
    #tech_tree_t1['has_bloodlines1']/=2

    tech_tree_t1['has_husbandry1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_husbandry'])
    #tech_tree_t1['has_husbandry1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_husbandry'])
    #tech_tree_t1['has_husbandry1']/=2

    tech_tree_t1['batteringramLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'batteringramLine'])
    #tech_tree_t1['batteringramLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'batteringramLine'])
    #tech_tree_t1['batteringramLine1']/=2

    tech_tree_t1['mangonelLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'mangonelLine'])
    #tech_tree_t1['mangonelLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'mangonelLine'])
    #tech_tree_t1['mangonelLine1']/=2

    tech_tree_t1['scorpionLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'scorpionLine'])
    #tech_tree_t1['scorpionLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'scorpionLine'])
    #tech_tree_t1['scorpionLine1']/=2

    tech_tree_t1['bombardcannonLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'bombardcannonLine'])
    #tech_tree_t1['bombardcannonLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'bombardcannonLine'])
    #tech_tree_t1['bombardcannonLine1']/=2

    tech_tree_t1['fireshipLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'fireshipLine'])
    #tech_tree_t1['fireshipLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'fireshipLine'])
    #tech_tree_t1['fireshipLine1']/=2

    tech_tree_t1['demolitionraftLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'demolitionraftLine'])
    #tech_tree_t1['demolitionraftLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'demolitionraftLine'])
    #tech_tree_t1['demolitionraftLine1']/=2

    tech_tree_t1['galleyLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'galleyLine'])
    #tech_tree_t1['galleyLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'galleyLine'])
    #tech_tree_t1['galleyLine1']/=2

    tech_tree_t1['cannongalleonLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'cannongalleonLine'])
    #tech_tree_t1['cannongalleonLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'cannongalleonLine'])
    #tech_tree_t1['cannongalleonLine1']/=2

    tech_tree_t1['has_drydock1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_drydock'])
    #tech_tree_t1['has_drydock1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_drydock'])
    #tech_tree_t1['has_drydock1']/=2

    tech_tree_t1['has_shipwright1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_shipwright'])
    #tech_tree_t1['has_shipwright1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_shipwright'])
    #tech_tree_t1['has_shipwright1']/=2

    tech_tree_t1['watchtowerLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'watchtowerLine'])
    #tech_tree_t1['watchtowerLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'watchtowerLine'])
    #tech_tree_t1['watchtowerLine1']/=2

    tech_tree_t1['stonewallLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'stonewallLine'])
    #tech_tree_t1['stonewallLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'stonewallLine'])
    #tech_tree_t1['stonewallLine1']/=2

    tech_tree_t1['piercearmorLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'piercearmorLine'])
    #tech_tree_t1['piercearmorLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'piercearmorLine'])
    #tech_tree_t1['piercearmorLine1']/=2

    tech_tree_t1['pierceatkLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'pierceatkLine'])
    #tech_tree_t1['pierceatkLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'pierceatkLine'])
    #tech_tree_t1['pierceatkLine1']/=2

    tech_tree_t1['meleeatkLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'meleeatkLine'])
    #tech_tree_t1['meleeatkLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'meleeatkLine'])
    #tech_tree_t1['meleeatkLine1']/=2

    tech_tree_t1['cavalryarmorLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarmorLine'])
    #tech_tree_t1['cavalryarmorLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarmorLine'])
    #tech_tree_t1['cavalryarmorLine1']/=2

    tech_tree_t1['infantryarmorLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'infantryarmorLine'])
    #tech_tree_t1['infantryarmorLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'infantryarmorLine'])
    #tech_tree_t1['infantryarmorLine1']/=2

    tech_tree_t1['has_faith1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_faith'])
    #tech_tree_t1['has_faith1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_faith'])
    #tech_tree_t1['has_faith1']/=2

    tech_tree_t1['has_redemption1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_redemption'])
    #tech_tree_t1['has_redemption1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_redemption'])
    #tech_tree_t1['has_redemption1']/=2

    tech_tree_t1['has_illumination1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_illumination'])
    #tech_tree_t1['has_illumination1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_illumination'])
    #tech_tree_t1['has_illumination1']/=2

    tech_tree_t1['has_atonement1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_atonement'])
    #tech_tree_t1['has_atonement1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_atonement'])
    #tech_tree_t1['has_atonement1']/=2

    tech_tree_t1['has_blockprinting1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_blockprinting'])
    #tech_tree_t1['has_blockprinting1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_blockprinting'])
    #tech_tree_t1['has_blockprinting1']/=2

    tech_tree_t1['has_herbalmedicine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_herbalmedicine'])
    #tech_tree_t1['has_herbalmedicine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_herbalmedicine'])
    #tech_tree_t1['has_herbalmedicine1']/=2

    tech_tree_t1['has_theocracy1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_theocracy'])
    #tech_tree_t1['has_theocracy1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_theocracy'])
    #tech_tree_t1['has_theocracy1']/=2

    tech_tree_t1['has_heresy1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_heresy'])
    #tech_tree_t1['has_heresy1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_heresy'])
    #tech_tree_t1['has_heresy1']/=2

    tech_tree_t1['has_sanctity1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_sanctity'])
    #tech_tree_t1['has_sanctity1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_sanctity'])
    #tech_tree_t1['has_sanctity1']/=2

    tech_tree_t1['has_fervor1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_fervor'])
    #tech_tree_t1['has_fervor1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_fervor'])
    #tech_tree_t1['has_fervor1']/=2

    tech_tree_t1['has_masonry1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_masonry'])
    #tech_tree_t1['has_masonry1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_masonry'])
    #tech_tree_t1['has_masonry1']/=2

    tech_tree_t1['has_architecture1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_architecture'])
    #tech_tree_t1['has_architecture1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_architecture'])
    #tech_tree_t1['has_architecture1']/=2

    tech_tree_t1['has_fortifiedwall1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_fortifiedwall'])
    #tech_tree_t1['has_fortifiedwall1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_fortifiedwall'])
    #tech_tree_t1['has_fortifiedwall1']/=2

    tech_tree_t1['has_bombardtower1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_bombardtower'])
    #tech_tree_t1['has_bombardtower1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_bombardtower'])
    #tech_tree_t1['has_bombardtower1']/=2

    tech_tree_t1['has_siegeengineers1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_siegeengineers'])
    #tech_tree_t1['has_siegeengineers1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_siegeengineers'])
    #tech_tree_t1['has_siegeengineers1']/=2

    tech_tree_t1['has_heatedshot1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_heatedshot'])
    #tech_tree_t1['has_heatedshot1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_heatedshot'])
    #tech_tree_t1['has_heatedshot1']/=2

    tech_tree_t1['has_arrowslits1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_arrowslits'])
    #tech_tree_t1['has_arrowslits1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_arrowslits'])
    #tech_tree_t1['has_arrowslits1']/=2

    tech_tree_t1['has_treadmillcrane1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_treadmillcrane'])
    #tech_tree_t1['has_treadmillcrane1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_treadmillcrane'])
    #tech_tree_t1['has_treadmillcrane1']/=2

    tech_tree_t1['goldLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'goldLine'])
    #tech_tree_t1['goldLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'goldLine'])
    #tech_tree_t1['goldLine1']/=2

    tech_tree_t1['stoneLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'stoneLine'])
    #tech_tree_t1['stoneLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'stoneLine'])
    #tech_tree_t1['stoneLine1']/=2

    tech_tree_t1['woodLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'woodLine'])
    #tech_tree_t1['woodLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'woodLine'])
    #tech_tree_t1['woodLine1']/=2

    tech_tree_t1['foodLine1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'foodLine'])
    #tech_tree_t1['foodLine1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'foodLine'])
    #tech_tree_t1['foodLine1']/=2

    tech_tree_t1['has_guilds1']=tech_tree_t1['Team1'].apply(lambda civ : tech_tree.loc[civ, 'has_guilds'])
    #tech_tree_t1['has_guilds1']+=tech_tree_t1['Team1Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_guilds'])
    #tech_tree_t1['has_guilds1']/=2
    
    return tech_tree_t1


    
def get_team2_specs():
    tech_tree_t2['militiaLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'militiaLine'])
    #tech_tree_t2['militiaLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'militiaLine'])
    #tech_tree_t2['militiaLine2']/=2

    tech_tree_t2['spearmanLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'spearmanLine'])
    #tech_tree_t2['spearmanLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'spearmanLine'])
    #tech_tree_t2['spearmanLine2']/=2

    tech_tree_t2['EaglescoutLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'EaglescoutLine'])
    #tech_tree_t2['EaglescoutLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'EaglescoutLine'])
    #tech_tree_t2['EaglescoutLine2']/=2

    tech_tree_t2['has_supplies2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_supplies'])
    #tech_tree_t2['has_supplies2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_supplies'])
    #tech_tree_t2['has_supplies2']/=2

    tech_tree_t2['has_squires2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_squires'])
    #tech_tree_t2['has_squires2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_squires'])
    #tech_tree_t2['has_squires2']/=2

    tech_tree_t2['has_arson2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_arson'])
    #tech_tree_t2['has_arson2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_arson'])
    #tech_tree_t2['has_arson2']/=2

    tech_tree_t2['archerLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'archerLine'])
    #tech_tree_t2['archerLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'archerLine'])
    #tech_tree_t2['archerLine2']/=2

    tech_tree_t2['skirmisherLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'skirmisherLine'])
    #tech_tree_t2['skirmisherLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'skirmisherLine'])
    #tech_tree_t2['skirmisherLine2']/=2

    tech_tree_t2['handcanoneerLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'handcanoneerLine'])
    #tech_tree_t2['handcanoneerLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'handcanoneerLine'])
    #tech_tree_t2['handcanoneerLine2']/=2

    tech_tree_t2['cavalryarcherLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarcherLine'])
    #tech_tree_t2['cavalryarcherLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarcherLine'])
    #tech_tree_t2['cavalryarcherLine2']/=2

    tech_tree_t2['has_thumbring2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_thumbring'])
    #tech_tree_t2['has_thumbring2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_thumbring'])
    #tech_tree_t2['has_thumbring2']/=2

    tech_tree_t2['has_parthiantactics2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_parthiantactics'])
    #tech_tree_t2['has_parthiantactics2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_parthiantactics'])
    #tech_tree_t2['has_parthiantactics2']/=2

    tech_tree_t2['scoutLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'scoutLine'])
    #tech_tree_t2['scoutLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'scoutLine'])
    #tech_tree_t2['scoutLine2']/=2

    tech_tree_t2['knightLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'knightLine'])
    #tech_tree_t2['knightLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'knightLine'])
    #tech_tree_t2['knightLine2']/=2

    tech_tree_t2['camelriderLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'camelriderLine'])
    #tech_tree_t2['camelriderLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'camelriderLine'])
    #tech_tree_t2['camelriderLine2']/=2

    tech_tree_t2['battleelephantLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'battleelephantLine'])
    #tech_tree_t2['battleelephantLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'battleelephantLine'])
    #tech_tree_t2['battleelephantLine2']/=2

    tech_tree_t2['steppelancerLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'steppelancerLine'])
    #tech_tree_t2['steppelancerLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'steppelancerLine'])
    #tech_tree_t2['steppelancerLine2']/=2

    tech_tree_t2['has_bloodlines2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_bloodlines'])
    #tech_tree_t2['has_bloodlines2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_bloodlines'])
    #tech_tree_t2['has_bloodlines2']/=2

    tech_tree_t2['has_husbandry2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_husbandry'])
    #tech_tree_t2['has_husbandry2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_husbandry'])
    #tech_tree_t2['has_husbandry2']/=2

    tech_tree_t2['batteringramLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'batteringramLine'])
    #tech_tree_t2['batteringramLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'batteringramLine'])
    #tech_tree_t2['batteringramLine2']/=2

    tech_tree_t2['mangonelLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'mangonelLine'])
    #tech_tree_t2['mangonelLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'mangonelLine'])
    #tech_tree_t2['mangonelLine2']/=2

    tech_tree_t2['scorpionLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'scorpionLine'])
    #tech_tree_t2['scorpionLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'scorpionLine'])
    #tech_tree_t2['scorpionLine2']/=2

    tech_tree_t2['bombardcannonLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'bombardcannonLine'])
    #tech_tree_t2['bombardcannonLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'bombardcannonLine'])
    #tech_tree_t2['bombardcannonLine2']/=2

    tech_tree_t2['fireshipLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'fireshipLine'])
    #tech_tree_t2['fireshipLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'fireshipLine'])
    #tech_tree_t2['fireshipLine2']/=2

    tech_tree_t2['demolitionraftLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'demolitionraftLine'])
    #tech_tree_t2['demolitionraftLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'demolitionraftLine'])
    #tech_tree_t2['demolitionraftLine2']/=2

    tech_tree_t2['galleyLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'galleyLine'])
    #tech_tree_t2['galleyLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'galleyLine'])
    #tech_tree_t2['galleyLine2']/=2

    tech_tree_t2['cannongalleonLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'cannongalleonLine'])
    #tech_tree_t2['cannongalleonLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'cannongalleonLine'])
    #tech_tree_t2['cannongalleonLine2']/=2

    tech_tree_t2['has_drydock2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_drydock'])
    #tech_tree_t2['has_drydock2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_drydock'])
    #tech_tree_t2['has_drydock2']/=2

    tech_tree_t2['has_shipwright2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_shipwright'])
    #tech_tree_t2['has_shipwright2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_shipwright'])
    #tech_tree_t2['has_shipwright2']/=2

    tech_tree_t2['watchtowerLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'watchtowerLine'])
    #tech_tree_t2['watchtowerLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'watchtowerLine'])
    #tech_tree_t2['watchtowerLine2']/=2

    tech_tree_t2['stonewallLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'stonewallLine'])
    #tech_tree_t2['stonewallLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'stonewallLine'])
    #tech_tree_t2['stonewallLine2']/=2

    tech_tree_t2['piercearmorLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'piercearmorLine'])
    #tech_tree_t2['piercearmorLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'piercearmorLine'])
    #tech_tree_t2['piercearmorLine2']/=2

    tech_tree_t2['pierceatkLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'pierceatkLine'])
    #tech_tree_t2['pierceatkLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'pierceatkLine'])
    #tech_tree_t2['pierceatkLine2']/=2

    tech_tree_t2['meleeatkLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'meleeatkLine'])
    #tech_tree_t2['meleeatkLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'meleeatkLine'])
    #tech_tree_t2['meleeatkLine2']/=2

    tech_tree_t2['cavalryarmorLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarmorLine'])
    #tech_tree_t2['cavalryarmorLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'cavalryarmorLine'])
    #tech_tree_t2['cavalryarmorLine2']/=2

    tech_tree_t2['infantryarmorLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'infantryarmorLine'])
    #tech_tree_t2['infantryarmorLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'infantryarmorLine'])
    #tech_tree_t2['infantryarmorLine2']/=2

    tech_tree_t2['has_faith2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_faith'])
    #tech_tree_t2['has_faith2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_faith'])
    #tech_tree_t2['has_faith2']/=2

    tech_tree_t2['has_redemption2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_redemption'])
    #tech_tree_t2['has_redemption2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_redemption'])
    #tech_tree_t2['has_redemption2']/=2

    tech_tree_t2['has_illumination2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_illumination'])
    #tech_tree_t2['has_illumination2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_illumination'])
    #tech_tree_t2['has_illumination2']/=2

    tech_tree_t2['has_atonement2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_atonement'])
    #tech_tree_t2['has_atonement2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_atonement'])
    #tech_tree_t2['has_atonement2']/=2

    tech_tree_t2['has_blockprinting2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_blockprinting'])
    #tech_tree_t2['has_blockprinting2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_blockprinting'])
    #tech_tree_t2['has_blockprinting2']/=2

    tech_tree_t2['has_herbalmedicine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_herbalmedicine'])
    #tech_tree_t2['has_herbalmedicine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_herbalmedicine'])
    #tech_tree_t2['has_herbalmedicine2']/=2

    tech_tree_t2['has_theocracy2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_theocracy'])
    #tech_tree_t2['has_theocracy2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_theocracy'])
    #tech_tree_t2['has_theocracy2']/=2

    tech_tree_t2['has_heresy2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_heresy'])
    #tech_tree_t2['has_heresy2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_heresy'])
    #tech_tree_t2['has_heresy2']/=2

    tech_tree_t2['has_sanctity2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_sanctity'])
    #tech_tree_t2['has_sanctity2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_sanctity'])
    #tech_tree_t2['has_sanctity2']/=2

    tech_tree_t2['has_fervor2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_fervor'])
    #tech_tree_t2['has_fervor2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_fervor'])
    #tech_tree_t2['has_fervor2']/=2

    tech_tree_t2['has_masonry2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_masonry'])
    #tech_tree_t2['has_masonry2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_masonry'])
    #tech_tree_t2['has_masonry2']/=2

    tech_tree_t2['has_architecture2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_architecture'])
    #tech_tree_t2['has_architecture2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_architecture'])
    #tech_tree_t2['has_architecture2']/=2

    tech_tree_t2['has_fortifiedwall2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_fortifiedwall'])
    #tech_tree_t2['has_fortifiedwall2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_fortifiedwall'])
    #tech_tree_t2['has_fortifiedwall2']/=2

    tech_tree_t2['has_bombardtower2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_bombardtower'])
    #tech_tree_t2['has_bombardtower2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_bombardtower'])
    #tech_tree_t2['has_bombardtower2']/=2

    tech_tree_t2['has_siegeengineers2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_siegeengineers'])
    #tech_tree_t2['has_siegeengineers2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_siegeengineers'])
    #tech_tree_t2['has_siegeengineers2']/=2

    tech_tree_t2['has_heatedshot2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_heatedshot'])
    #tech_tree_t2['has_heatedshot2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_heatedshot'])
    #tech_tree_t2['has_heatedshot2']/=2

    tech_tree_t2['has_arrowslits2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_arrowslits'])
    #tech_tree_t2['has_arrowslits2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_arrowslits'])
    #tech_tree_t2['has_arrowslits2']/=2

    tech_tree_t2['has_treadmillcrane2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_treadmillcrane'])
    #tech_tree_t2['has_treadmillcrane2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_treadmillcrane'])
    #tech_tree_t2['has_treadmillcrane2']/=2

    tech_tree_t2['goldLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'goldLine'])
    #tech_tree_t2['goldLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'goldLine'])
    #tech_tree_t2['goldLine2']/=2

    tech_tree_t2['stoneLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'stoneLine'])
    #tech_tree_t2['stoneLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'stoneLine'])
    #tech_tree_t2['stoneLine2']/=2

    tech_tree_t2['woodLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'woodLine'])
    #tech_tree_t2['woodLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'woodLine'])
    #tech_tree_t2['woodLine2']/=2

    tech_tree_t2['foodLine2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'foodLine'])
    #tech_tree_t2['foodLine2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'foodLine'])
    #tech_tree_t2['foodLine2']/=2

    tech_tree_t2['has_guilds2']=tech_tree_t2['Team2'].apply(lambda civ : tech_tree.loc[civ, 'has_guilds'])
    #tech_tree_t2['has_guilds2']+=tech_tree_t2['Team2Civ2'].apply(lambda civ : tech_tree.loc[civ, 'has_guilds'])
    #tech_tree_t2['has_guilds2']/=2

    return tech_tree_t2

# %%
df['duration']=df['duration'].astype('category')
df['has_relevant_water']=df['has_relevant_water'].astype('category')
df
# Out:
#        duration has_relevant_water       Team1       Team2
# 0        medium              False     Magyars      Franks
# 1         short              False       Slavs      Mayans
# 2         short              False  Byzantines     Chinese
# 4         short              False      Mayans        Huns
# 5         short              False    Saracens  Byzantines
# ...         ...                ...         ...         ...
# 137363    short              False     Mongols     Berbers
# 137367    short              False     Spanish      Cumans
# 137371    short              False     Mongols      Aztecs
# 137372   medium              False      Franks       Incas
# 137374    short              False        Huns      Aztecs
#
# [68520 rows x 4 columns]

# %%
df=df.dropna().reset_index().drop('index', 1)
df
# Out:
#       duration has_relevant_water       Team1       Team2
# 0       medium              False     Magyars      Franks
# 1        short              False       Slavs      Mayans
# 2        short              False  Byzantines     Chinese
# 3        short              False      Mayans        Huns
# 4        short              False    Saracens  Byzantines
# ...        ...                ...         ...         ...
# 68515    short              False     Mongols     Berbers
# 68516    short              False     Spanish      Cumans
# 68517    short              False     Mongols      Aztecs
# 68518   medium              False      Franks       Incas
# 68519    short              False        Huns      Aztecs
#
# [68520 rows x 4 columns]

# %%
tech_tree
# Out:
#              militiaLine  spearmanLine  EaglescoutLine  has_supplies  \
# Britons                3             3               0             1
# Byzantines             3             3               0             1
# Celts                  3             3               0             1
# Chinese                3             3               0             0
# Franks                 3             3               0             1
# Goths                  3             3               0             0
# Japanese               3             3               0             1
# Mongols                3             2               0             0
# Persians               1             3               0             1
# Saracens               3             2               0             1
# Teutons                3             3               0             1
# Turks                  3             1               0             1
# Vikings                3             2               0             1
# ...

# %%
tech_tree_t1 = df[["Team1"]]
tech_tree_t1
# Out:
#             Team1
# 0         Magyars
# 1           Slavs
# 2      Byzantines
# 3          Mayans
# 4        Saracens
# ...           ...
# 68515     Mongols
# 68516     Spanish
# 68517     Mongols
# 68518      Franks
# 68519        Huns
#
# [68520 rows x 1 columns]

# %%
tech_tree_t2 = df[["Team2"]]
tech_tree_t2
# Out:
#             Team2
# 0          Franks
# 1          Mayans
# 2         Chinese
# 3            Huns
# 4      Byzantines
# ...           ...
# 68515     Berbers
# 68516      Cumans
# 68517      Aztecs
# 68518       Incas
# 68519      Aztecs
#
# [68520 rows x 1 columns]

# %%
res =   pandas.DataFrame(columns=['militiaLine1','spearmanLine1','EaglescoutLine1','has_supplies1','has_squires1','has_arson1','archerLine1','skirmisherLine1','handcanoneerLine1','cavalryarcherLine1','has_thumbring1','has_parthiantactics1','scoutLine1','knightLine1','camelriderLine1','battleelephantLine1','steppelancerLine1','has_bloodlines1','has_husbandry1','batteringramLine1','mangonelLine1','scorpionLine1','bombardcannonLine1','fireshipLine1','demolitionraftLine1','galleyLine1','cannongalleonLine1','has_drydock1','has_shipwright1','watchtowerLine1','stonewallLine1','piercearmorLine1','pierceatkLine1','meleeatkLine1','cavalryarmorLine1','infantryarmorLine1','has_faith1','has_redemption1','has_illumination1','has_atonement1','has_blockprinting1','has_herbalmedicine1','has_theocracy1','has_heresy1','has_sanctity1','has_fervor1','has_masonry1','has_architecture1','has_fortifiedwall1','has_bombardtower1','has_siegeengineers1','has_heatedshot1','has_arrowslits1','has_treadmillcrane1','goldLine1','stoneLine1','woodLine1','foodLine1','has_guilds1'])
res2 =  pandas.DataFrame(columns=['militiaLine2','spearmanLine2','EaglescoutLine2','has_supplies2','has_squires2','has_arson2','archerLine2','skirmisherLine2','handcanoneerLine2','cavalryarcherLine2','has_thumbring2','has_parthiantactics2','scoutLine2','knightLine2','camelriderLine2','battleelephantLine2','steppelancerLine2','has_bloodlines2','has_husbandry2','batteringramLine2','mangonelLine2','scorpionLine2','bombardcannonLine2','fireshipLine2','demolitionraftLine2','galleyLine2','cannongalleonLine2','has_drydock2','has_shipwright2','watchtowerLine2','stonewallLine2','piercearmorLine2','pierceatkLine2','meleeatkLine2','cavalryarmorLine2','infantryarmorLine2','has_faith2','has_redemption2','has_illumination2','has_atonement2','has_blockprinting2','has_herbalmedicine2','has_theocracy2','has_heresy2','has_sanctity2','has_fervor2','has_masonry2','has_architecture2','has_fortifiedwall2','has_bombardtower2','has_siegeengineers2','has_heatedshot2','has_arrowslits2','has_treadmillcrane2','goldLine2','stoneLine2','woodLine2','foodLine2','has_guilds2'])
res
# Out:
# Empty DataFrame
# Columns: [militiaLine1, spearmanLine1, EaglescoutLine1, has_supplies1, has_squires1, has_arson1, archerLine1, skirmisherLine1, handcanoneerLine1, cavalryarcherLine1, has_thumbring1, has_parthiantactics1, scoutLine1, knightLine1, camelriderLine1, battleelephantLine1, steppelancerLine1, has_bloodlines1, has_husbandry1, batteringramLine1, mangonelLine1, scorpionLine1, bombardcannonLine1, fireshipLine1, demolitionraftLine1, galleyLine1, cannongalleonLine1, has_drydock1, has_shipwright1, watchtowerLine1, stonewallLine1, piercearmorLine1, pierceatkLine1, meleeatkLine1, cavalryarmorLine1, infantryarmorLine1, has_faith1, has_redemption1, has_illumination1, has_atonement1, has_blockprinting1, has_herbalmedicine1, has_theocracy1, has_heresy1, has_sanctity1, has_fervor1, has_masonry1, has_architecture1, has_fortifiedwall1, has_bombardtower1, has_siegeengineers1, has_heatedshot1, has_arrowslits1, has_treadmillcrane1, goldLine1, stoneLine1, woodLine1, foodLine1, has_guilds1]
# ...

# %%
tech_tree_t2 = pandas.concat([tech_tree_t2, res2])
tech_tree_t1 = pandas.concat([tech_tree_t1, res])

# %%
tech_tree_t1 = get_team1_specs()
tech_tree_t1
# Out:
#             Team1  militiaLine1  spearmanLine1  EaglescoutLine1  \
# 0         Magyars             3              3                0
# 1           Slavs             3              3                0
# 2      Byzantines             3              3                0
# 3          Mayans             2              3                3
# 4        Saracens             3              2                0
# ...           ...           ...            ...              ...
# 68515     Mongols             3              2                0
# 68516     Spanish             3              3                0
# 68517     Mongols             3              2                0
# 68518      Franks             3              3                0
# 68519        Huns             2              3                0
#
#        has_supplies1  has_squires1  has_arson1  archerLine1  skirmisherLine1  \
# 0                  1             0           1            3                2
# ...

# %%
tech_tree_t2 = get_team2_specs()
tech_tree_t2
# Out:
#             Team2  militiaLine2  spearmanLine2  EaglescoutLine2  \
# 0          Franks             3              3                0
# 1          Mayans             2              3                3
# 2         Chinese             3              3                0
# 3            Huns             2              3                0
# 4      Byzantines             3              3                0
# ...           ...           ...            ...              ...
# 68515     Berbers             3              2                0
# 68516      Cumans             3              3                0
# 68517      Aztecs             3              2                3
# 68518       Incas             3              3                3
# 68519      Aztecs             3              2                3
#
#        has_supplies2  has_squires2  has_arson2  archerLine2  skirmisherLine2  \
# 0                  1             1           1            2                2
# ...

# %%
tech_tree_full = pandas.concat([tech_tree_t1.reset_index(drop=True),tech_tree_t2.reset_index(drop=True)], axis=1)
tech_tree_full
# Out:
#             Team1  militiaLine1  spearmanLine1  EaglescoutLine1  \
# 0         Magyars             3              3                0
# 1           Slavs             3              3                0
# 2      Byzantines             3              3                0
# 3          Mayans             2              3                3
# 4        Saracens             3              2                0
# ...           ...           ...            ...              ...
# 68515     Mongols             3              2                0
# 68516     Spanish             3              3                0
# 68517     Mongols             3              2                0
# 68518      Franks             3              3                0
# 68519        Huns             2              3                0
#
#        has_supplies1  has_squires1  has_arson1  archerLine1  skirmisherLine1  \
# 0                  1             0           1            3                2
# ...

# %%
vicTeam = df['duration'].dropna()
vicTeam
# Out:
# 0        medium
# 1         short
# 2         short
# 3         short
# 4         short
#           ...
# 68515     short
# 68516     short
# 68517     short
# 68518    medium
# 68519     short
# Name: duration, Length: 68520, dtype: category
# Categories (3, object): ['long', 'medium', 'short']

# %%
output=pandas.concat([pandas.concat([df.drop(['Team1','Team2','duration'], axis = 1).reset_index(drop=True),tech_tree_full.drop(['Team1','Team2'], axis = 1).reset_index(drop=True)], axis = 1), df['duration']], axis = 1)
output
# Out:
#       has_relevant_water  militiaLine1  spearmanLine1  EaglescoutLine1  \
# 0                  False             3              3                0
# 1                  False             3              3                0
# 2                  False             3              3                0
# 3                  False             2              3                3
# 4                  False             3              2                0
# ...                  ...           ...            ...              ...
# 68515              False             3              2                0
# 68516              False             3              3                0
# 68517              False             3              2                0
# 68518              False             3              3                0
# 68519              False             2              3                0
#
#        has_supplies1  has_squires1  has_arson1  archerLine1  skirmisherLine1  \
# ...

# %%
output.to_json('input_dataset.json')
